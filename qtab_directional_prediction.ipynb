# %% [markdown]
# ENGINEERING CNN-LSTM BASED ON COMBINED_DATASET

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

combined_data = pd.read_csv('combined_dataset.csv')

combined_data = combined_data[::-1].reset_index(drop=True)

combined_data = combined_data.applymap(
    lambda x: float(str(x).lstrip("'")) if isinstance(x, (int, float, str)) and str(x).startswith("'") else x
)

column_to_move = 'change'
columns = [col for col in combined_data.columns if col != column_to_move] + [column_to_move]
combined_data = combined_data[columns]

combined_data['directional_change'] = combined_data['change'].apply(lambda x: x > 0)

combined_data.head()
# Out:
# <ipython-input-42-1b583b49e06e>:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   combined_data = combined_data.applymap(
#          Date  OJ_Open  OJ_High  OJ_Low  OJ_Close  OJ_adj_close  OJ_Volume  \
# 0  2007-07-30   141.75   142.00  139.00    139.70        139.70     1836.0
# 1  2007-07-31   139.00   141.15  138.65    140.00        140.00     1746.0
# 2  2007-08-01   140.10   141.80  139.00    139.15        139.15     2290.0
# 3  2007-08-02   140.00   141.75  139.20    141.25        141.25     2153.0
# 4  2007-08-03   140.00   142.50  135.10    142.45        142.45     2476.0
#
#      Open    High     Low  ...  Corn_adj_close  Corn_Volume  Soybean_Open  \
# 0  112.50  113.45  111.60  ...          323.50      25315.0         818.0
# 1  112.95  114.40  112.50  ...          325.75      30891.0         823.5
# 2  113.80  114.50  112.75  ...          319.00      25569.0         834.5
# 3  113.15  116.60  113.15  ...          324.00      20120.0         827.0
# 4  116.50  118.40  116.20  ...          326.50      24814.0         833.0
#
#    Soybean_High  Soybean_Low  Soybean_Close  Soybean_adj_close  \
# 0        825.00       815.50         822.75             822.75
# 1        838.00       823.50         834.00             834.00
# 2        842.75       823.50         825.75             825.75
# 3        835.50       826.75         831.00             831.00
# 4        841.25       833.00         839.00             839.00
#
#    Soybean_Volume  change  directional_change
# 0         19018.0    1.35                True
# 1         11921.0   -1.20               False
# 2         10742.0    3.10                True
# 3          5663.0    1.45                True
# 4          4781.0    0.75                True
#
# [5 rows x 76 columns]

# %%
combined_data = combined_data.fillna(method="ffill").fillna(method="bfill")

features_for_pca = combined_data.drop(columns=["Date", "change", "directional_change"])

scaler = MinMaxScaler()
normalized_features = scaler.fit_transform(features_for_pca)

# Apply PCA
pca = PCA(n_components=0.95)
reduced_features = pca.fit_transform(normalized_features)

reduced_features_df = pd.DataFrame(
    reduced_features, columns=[f"PC{i+1}" for i in range(reduced_features.shape[1])]
)

# Add the Date and target column ('change') back into the new dataset
reduced_features_df["Date"] = combined_data["Date"].values
reduced_features_df["change"] = combined_data["change"].values
reduced_features_df["directional_change"] = combined_data["directional_change"].values
# Out:
# <ipython-input-43-47190f353159>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_data = combined_data.fillna(method="ffill").fillna(method="bfill")

# %%
# TRUE MEANS POSITIVE CHANGE, FALSE MEANS NEGATIVE --> WILL MAP TO 1 AND 0 LATER
reduced_features_df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -1.816830 -0.804564 -0.041428  0.047606  0.574845  0.302695 -0.469479
# 1 -1.783443 -0.819261 -0.053107  0.079708  0.594746  0.302641 -0.216791
# 2 -1.784261 -0.776942 -0.080797  0.102393  0.532047  0.316983  0.049040
# 3 -1.769021 -0.764975 -0.076466  0.099041  0.520718  0.324865  0.301018
# 4 -1.750549 -0.785042 -0.084596  0.097922  0.520101  0.336285  0.549084
#
#         PC8       PC9      PC10      PC11      PC12      PC13      PC14  \
# 0 -0.078834  0.068924  0.111088 -0.098367 -0.073523 -0.085615 -0.147709
# 1 -0.046196  0.115104  0.029543 -0.053936 -0.075321 -0.131259 -0.162499
# 2  0.146209  0.096331  0.094213 -0.053582 -0.120693 -0.117246 -0.144571
# 3  0.176992  0.114158  0.086755 -0.009093 -0.084593 -0.065193 -0.154241
# 4  0.152172  0.163222  0.060858 -0.053994 -0.096616 -0.106836 -0.150627
#
#        PC15      PC16      PC17        Date  change  directional_change
# 0  0.101647 -0.343325  0.283100  2007-07-30    1.35                True
# 1  0.024478 -0.329540  0.307166  2007-07-31   -1.20               False
# 2 -0.057293 -0.100491  0.193179  2007-08-01    3.10                True
# 3 -0.112280 -0.075273  0.166903  2007-08-02    1.45                True
# 4 -0.077779 -0.107441  0.179963  2007-08-03    0.75                True

# %% [markdown]
# DIRECTIONAL CHANGES

# %%
X = reduced_features_df.drop(columns=["Date", "directional_change"]).values
y = reduced_features_df["directional_change"].astype(int).values  # Ensure y is binary (0/1)

split_idx = int(0.8 * len(X))
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

TIME_STEPS = 1
FEATURES = X_train.shape[1]

X_train_reshaped = X_train.reshape(X_train.shape[0], TIME_STEPS, FEATURES)
X_test_reshaped = X_test.reshape(X_test.shape[0], TIME_STEPS, FEATURES)

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, Flatten, Dropout, Reshape
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# CNN-LSTM Model (Binary Classification)
def build_cnn_lstm(input_shape):
    model = Sequential([
        Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=input_shape),
        Dropout(0.3),
        Flatten(),
        Reshape((1, 128)),
        LSTM(100, return_sequences=False),
        Dropout(0.3),
        Dense(100, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')  # Sigmoid activation for binary classification
    ])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# LSTM-CNN Model (Binary Classification)
def build_lstm_cnn(input_shape):
    model = Sequential([
        LSTM(100, return_sequences=True, input_shape=input_shape),
        Dropout(0.3),
        Conv1D(filters=128, kernel_size=1, activation='relu'),
        MaxPooling1D(pool_size=1),
        Flatten(),
        Dense(100, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')  # Sigmoid activation for binary classification
    ])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Train and Evaluate Function
def train_and_evaluate(model, X_train, y_train, X_test, y_test, batch_size=32, epochs=25):
    model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.2, verbose=1)
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
    return model

print("Training CNN-LSTM Model...")
cnn_lstm_model = build_cnn_lstm(input_shape=(TIME_STEPS, FEATURES))
cnn_lstm_model = train_and_evaluate(cnn_lstm_model, X_train_reshaped, y_train, X_test_reshaped, y_test)

print("\nTraining LSTM-CNN Model...")
lstm_cnn_model = build_lstm_cnn(input_shape=(TIME_STEPS, FEATURES))
lstm_cnn_model = train_and_evaluate(lstm_cnn_model, X_train_reshaped, y_train, X_test_reshaped, y_test)

y_pred_cnn_lstm = (cnn_lstm_model.predict(X_test_reshaped).flatten() > 0.5).astype(int)
y_pred_lstm_cnn = (lstm_cnn_model.predict(X_test_reshaped).flatten() > 0.5).astype(int)

# Create seperate test set so that we can see the results easier
testing_set = reduced_features_df.iloc[split_idx:].copy()
testing_set['predicted_cnn_lstm'] = y_pred_cnn_lstm
testing_set['predicted_lstm_cnn'] = y_pred_lstm_cnn
testing_set['actual_directional_change'] = y_test

testing_set['cnn_lstm_correct'] = testing_set['predicted_cnn_lstm'] == testing_set['actual_directional_change']
testing_set['lstm_cnn_correct'] = testing_set['predicted_lstm_cnn'] == testing_set['actual_directional_change']

cnn_lstm_correct_rows = testing_set[testing_set['cnn_lstm_correct']]
cnn_lstm_incorrect_rows = testing_set[~testing_set['cnn_lstm_correct']]

lstm_cnn_correct_rows = testing_set[testing_set['lstm_cnn_correct']]
lstm_cnn_incorrect_rows = testing_set[~testing_set['lstm_cnn_correct']]

# summary
print("\nSummary:")
print(f"CNN-LSTM Correct Predictions: {len(cnn_lstm_correct_rows)}")
print(f"CNN-LSTM Incorrect Predictions: {len(cnn_lstm_incorrect_rows)}")
print(f"LSTM-CNN Correct Predictions: {len(lstm_cnn_correct_rows)}")
print(f"LSTM-CNN Incorrect Predictions: {len(lstm_cnn_incorrect_rows)}")

# Display examples of correct and incorrect predictions
print("\nExamples of CNN-LSTM Correct Predictions:\n", cnn_lstm_correct_rows.head())
print("\nExamples of CNN-LSTM Incorrect Predictions:\n", cnn_lstm_incorrect_rows.head())
print("\nExamples of LSTM-CNN Correct Predictions:\n", lstm_cnn_correct_rows.head())
print("\nExamples of LSTM-CNN Incorrect Predictions:\n", lstm_cnn_incorrect_rows.head())
# Out:
# Training CNN-LSTM Model...
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9017 - loss: 0.4056 - val_accuracy: 0.9889 - val_loss: 0.0471
# Epoch 2/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9791 - loss: 0.0458 - val_accuracy: 0.9952 - val_loss: 0.0273
# Epoch 3/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9860 - loss: 0.0335 - val_accuracy: 0.9905 - val_loss: 0.0275
# Epoch 4/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9914 - loss: 0.0202 - val_accuracy: 0.9952 - val_loss: 0.0199
# Epoch 5/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9905 - loss: 0.0230 - val_accuracy: 0.9905 - val_loss: 0.0237
# Epoch 6/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9930 - loss: 0.0186 - val_accuracy: 0.9984 - val_loss: 0.0125
# Epoch 7/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9948 - loss: 0.0147 - val_accuracy: 0.9921 - val_loss: 0.0190
# Epoch 8/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9946 - loss: 0.0119 - val_accuracy: 0.9952 - val_loss: 0.0132
# Epoch 9/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9987 - loss: 0.0063 - val_accuracy: 0.9968 - val_loss: 0.0105
# Epoch 10/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9928 - loss: 0.0177 - val_accuracy: 0.9952 - val_loss: 0.0131
# Epoch 11/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9982 - loss: 0.0079 - val_accuracy: 0.9984 - val_loss: 0.0123
# Epoch 12/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9959 - loss: 0.0102 - val_accuracy: 0.9984 - val_loss: 0.0089
# Epoch 13/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9942 - loss: 0.0207 - val_accuracy: 0.9968 - val_loss: 0.0099
# Epoch 14/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9970 - loss: 0.0086 - val_accuracy: 0.9984 - val_loss: 0.0095
# Epoch 15/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9958 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 16/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9976 - loss: 0.0054 - val_accuracy: 0.9952 - val_loss: 0.0134
# Epoch 17/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9959 - loss: 0.0079 - val_accuracy: 0.9984 - val_loss: 0.0067
# Epoch 18/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9985 - loss: 0.0072 - val_accuracy: 0.9984 - val_loss: 0.0093
# Epoch 19/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9976 - loss: 0.0060 - val_accuracy: 0.9984 - val_loss: 0.0093
# Epoch 20/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9984 - loss: 0.0037 - val_accuracy: 0.9968 - val_loss: 0.0092
# Epoch 21/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9992 - loss: 0.0045 - val_accuracy: 0.9968 - val_loss: 0.0138
# Epoch 22/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9991 - loss: 0.0037 - val_accuracy: 0.9937 - val_loss: 0.0179
# Epoch 23/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9980 - loss: 0.0032 - val_accuracy: 0.9952 - val_loss: 0.0199
# Epoch 24/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9968 - loss: 0.0059 - val_accuracy: 0.9937 - val_loss: 0.0233
# Epoch 25/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9937 - val_loss: 0.0178
# Test Loss: 0.0102, Test Accuracy: 0.9962
#
# Training LSTM-CNN Model...
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9174 - loss: 0.4431 - val_accuracy: 0.9842 - val_loss: 0.0559
# Epoch 2/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9876 - loss: 0.0355 - val_accuracy: 0.9937 - val_loss: 0.0297
# Epoch 3/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9913 - loss: 0.0226 - val_accuracy: 0.9984 - val_loss: 0.0174
# Epoch 4/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9916 - loss: 0.0206 - val_accuracy: 0.9937 - val_loss: 0.0195
# Epoch 5/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9966 - loss: 0.0136 - val_accuracy: 0.9937 - val_loss: 0.0185
# Epoch 6/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9965 - loss: 0.0099 - val_accuracy: 0.9905 - val_loss: 0.0193
# Epoch 7/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9962 - loss: 0.0097 - val_accuracy: 0.9952 - val_loss: 0.0152
# Epoch 8/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9950 - loss: 0.0151 - val_accuracy: 0.9952 - val_loss: 0.0125
# Epoch 9/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9959 - loss: 0.0095 - val_accuracy: 0.9984 - val_loss: 0.0090
# Epoch 10/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9960 - loss: 0.0102 - val_accuracy: 0.9968 - val_loss: 0.0103
# Epoch 11/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9968 - loss: 0.0074 - val_accuracy: 0.9952 - val_loss: 0.0096
# Epoch 12/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9962 - loss: 0.0087 - val_accuracy: 0.9937 - val_loss: 0.0139
# Epoch 13/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9972 - loss: 0.0090 - val_accuracy: 0.9968 - val_loss: 0.0108
# Epoch 14/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9957 - loss: 0.0091 - val_accuracy: 0.9952 - val_loss: 0.0102
# Epoch 15/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9934 - loss: 0.0135 - val_accuracy: 0.9968 - val_loss: 0.0081
# Epoch 16/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9997 - loss: 0.0033 - val_accuracy: 0.9984 - val_loss: 0.0083
# Epoch 17/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9985 - loss: 0.0037 - val_accuracy: 0.9984 - val_loss: 0.0053
# Epoch 18/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9989 - loss: 0.0036 - val_accuracy: 0.9968 - val_loss: 0.0110
# Epoch 19/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9974 - loss: 0.0080 - val_accuracy: 0.9968 - val_loss: 0.0053
# Epoch 20/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9983 - loss: 0.0031 - val_accuracy: 0.9984 - val_loss: 0.0076
# Epoch 21/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9950 - loss: 0.0137 - val_accuracy: 0.9984 - val_loss: 0.0073
# Epoch 22/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9985 - loss: 0.0031 - val_accuracy: 0.9984 - val_loss: 0.0056
# Epoch 23/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9988 - loss: 0.0031 - val_accuracy: 0.9968 - val_loss: 0.0082
# Epoch 24/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 0.9984 - val_loss: 0.0066
# Epoch 25/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9979 - loss: 0.0036 - val_accuracy: 0.9937 - val_loss: 0.0147
# Test Loss: 0.0075, Test Accuracy: 0.9962
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# Summary:
# CNN-LSTM Correct Predictions: 786
# CNN-LSTM Incorrect Predictions: 3
# LSTM-CNN Correct Predictions: 786
# LSTM-CNN Incorrect Predictions: 3
#
# Examples of CNN-LSTM Correct Predictions:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 3152  1.054851  0.034722  0.206307 -0.217560  0.486899 -0.836237 -0.487225
# 3153  1.076072  0.094690  0.215062 -0.167040  0.454212 -0.736391 -0.252613
# 3154  1.019462  0.116346  0.238971 -0.279298  0.495184 -0.678906  0.004204
# 3155  1.111319  0.025400  0.188051 -0.084522  0.457223 -0.776876  0.253034
# 3156  1.200448  0.044285  0.195144 -0.150152  0.194009 -0.752799  0.522288
#
#            PC8       PC9      PC10  ...      PC16      PC17        Date  \
# 3152  0.188518 -0.048016 -0.303726  ...  0.140101 -0.300833  2021-05-24
# 3153 -0.068867  0.005042 -0.216872  ... -0.034141 -0.174238  2021-05-25
# 3154 -0.046611  0.033794 -0.236260  ...  0.370548 -0.480484  2021-05-26
# 3155  0.211066  0.064799 -0.481039  ... -0.108287 -0.262874  2021-05-27
# 3156  0.387640 -0.050363  0.061684  ... -0.207577 -0.209860  2021-05-28
#
#       change  directional_change  predicted_cnn_lstm  predicted_lstm_cnn  \
# 3152    1.50                True                   1                   1
# 3153    5.20                True                   1                   1
# 3154   -0.35               False                   0                   0
# 3155    7.00                True                   1                   1
# 3156   -1.30               False                   0                   0
#
#      actual_directional_change  cnn_lstm_correct  lstm_cnn_correct
# 3152                         1              True              True
# 3153                         1              True              True
# 3154                         0              True              True
# 3155                         1              True              True
# 3156                         0              True              True
#
# [5 rows x 25 columns]
#
# Examples of CNN-LSTM Incorrect Predictions:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 3208  0.788487  0.405771 -0.089291 -0.169568  0.370120 -0.327066  0.282953
# 3698  0.681259  0.812396 -0.859326 -0.784980 -0.197320 -0.005984  0.542789
# 3905  0.756781  1.045766 -0.078459 -1.156192  0.582744  1.323575 -0.233685
#
#            PC8       PC9      PC10  ...      PC16      PC17        Date  \
# 3208  0.349580 -0.170157 -0.061549  ... -0.025012 -0.080687  2021-08-19
# 3698  0.324290  0.152521  0.392111  ... -0.047978  0.175152  2023-10-06
# 3905  0.129782  0.132694 -0.217897  ...  0.000789  0.124343  2024-08-20
#
#       change  directional_change  predicted_cnn_lstm  predicted_lstm_cnn  \
# 3208    0.05                True                   0                   0
# 3698    0.00               False                   1                   1
# 3905    0.00               False                   1                   1
#
#      actual_directional_change  cnn_lstm_correct  lstm_cnn_correct
# 3208                         1             False             False
# 3698                         0             False             False
# 3905                         0             False             False
#
# [3 rows x 25 columns]
#
# Examples of LSTM-CNN Correct Predictions:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 3152  1.054851  0.034722  0.206307 -0.217560  0.486899 -0.836237 -0.487225
# 3153  1.076072  0.094690  0.215062 -0.167040  0.454212 -0.736391 -0.252613
# 3154  1.019462  0.116346  0.238971 -0.279298  0.495184 -0.678906  0.004204
# 3155  1.111319  0.025400  0.188051 -0.084522  0.457223 -0.776876  0.253034
# 3156  1.200448  0.044285  0.195144 -0.150152  0.194009 -0.752799  0.522288
#
#            PC8       PC9      PC10  ...      PC16      PC17        Date  \
# 3152  0.188518 -0.048016 -0.303726  ...  0.140101 -0.300833  2021-05-24
# 3153 -0.068867  0.005042 -0.216872  ... -0.034141 -0.174238  2021-05-25
# 3154 -0.046611  0.033794 -0.236260  ...  0.370548 -0.480484  2021-05-26
# 3155  0.211066  0.064799 -0.481039  ... -0.108287 -0.262874  2021-05-27
# 3156  0.387640 -0.050363  0.061684  ... -0.207577 -0.209860  2021-05-28
#
#       change  directional_change  predicted_cnn_lstm  predicted_lstm_cnn  \
# 3152    1.50                True                   1                   1
# 3153    5.20                True                   1                   1
# 3154   -0.35               False                   0                   0
# 3155    7.00                True                   1                   1
# 3156   -1.30               False                   0                   0
#
#      actual_directional_change  cnn_lstm_correct  lstm_cnn_correct
# 3152                         1              True              True
# 3153                         1              True              True
# 3154                         0              True              True
# 3155                         1              True              True
# 3156                         0              True              True
#
# [5 rows x 25 columns]
#
# Examples of LSTM-CNN Incorrect Predictions:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 3208  0.788487  0.405771 -0.089291 -0.169568  0.370120 -0.327066  0.282953
# 3698  0.681259  0.812396 -0.859326 -0.784980 -0.197320 -0.005984  0.542789
# 3905  0.756781  1.045766 -0.078459 -1.156192  0.582744  1.323575 -0.233685
#
#            PC8       PC9      PC10  ...      PC16      PC17        Date  \
# 3208  0.349580 -0.170157 -0.061549  ... -0.025012 -0.080687  2021-08-19
# 3698  0.324290  0.152521  0.392111  ... -0.047978  0.175152  2023-10-06
# 3905  0.129782  0.132694 -0.217897  ...  0.000789  0.124343  2024-08-20
#
#       change  directional_change  predicted_cnn_lstm  predicted_lstm_cnn  \
# 3208    0.05                True                   0                   0
# 3698    0.00               False                   1                   1
# 3905    0.00               False                   1                   1
#
#      actual_directional_change  cnn_lstm_correct  lstm_cnn_correct
# 3208                         1             False             False
# 3698                         0             False             False
# 3905                         0             False             False
#
# [3 rows x 25 columns]

# %%
testing_set.head()
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 3152  1.054851  0.034722  0.206307 -0.217560  0.486899 -0.836237 -0.487225
# 3153  1.076072  0.094690  0.215062 -0.167040  0.454212 -0.736391 -0.252613
# 3154  1.019462  0.116346  0.238971 -0.279298  0.495184 -0.678906  0.004204
# 3155  1.111319  0.025400  0.188051 -0.084522  0.457223 -0.776876  0.253034
# 3156  1.200448  0.044285  0.195144 -0.150152  0.194009 -0.752799  0.522288
#
#            PC8       PC9      PC10  ...      PC16      PC17        Date  \
# 3152  0.188518 -0.048016 -0.303726  ...  0.140101 -0.300833  2021-05-24
# 3153 -0.068867  0.005042 -0.216872  ... -0.034141 -0.174238  2021-05-25
# 3154 -0.046611  0.033794 -0.236260  ...  0.370548 -0.480484  2021-05-26
# 3155  0.211066  0.064799 -0.481039  ... -0.108287 -0.262874  2021-05-27
# 3156  0.387640 -0.050363  0.061684  ... -0.207577 -0.209860  2021-05-28
#
#       change  directional_change  predicted_cnn_lstm  predicted_lstm_cnn  \
# 3152    1.50                True                   1                   1
# 3153    5.20                True                   1                   1
# 3154   -0.35               False                   0                   0
# 3155    7.00                True                   1                   1
# 3156   -1.30               False                   0                   0
#
#      actual_directional_change  cnn_lstm_correct  lstm_cnn_correct
# 3152                         1              True              True
# 3153                         1              True              True
# 3154                         0              True              True
# 3155                         1              True              True
# 3156                         0              True              True
#
# [5 rows x 25 columns]
